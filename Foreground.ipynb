# %% [markdown]
# <a href="https://colab.research.google.com/github/GrainSack/GrainSack/blob/main/Foreground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install visdom dominate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 63.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408196 sha256=db22c43ea8e6e5a7f54014aa26fa5977a26726c2b76b4444f601efa6daa2ca1f
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# Successfully built visdom
# ...

# %%
# !git clone https://github.com/lyndonzheng/Pluralistic
# !cd Pluralistic
# Out:
# Cloning into 'Pluralistic'...
# remote: Enumerating objects: 334, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 334 (delta 2), reused 20 (delta 2), pack-reused 310
# Receiving objects: 100% (334/334), 172.16 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !python test.py  --name celeba_random --img_file /content/Pluralistic/images/face_playing
# Out:
# --------------Options--------------
# batchSize: 8
# checkpoints_dir: ./checkpoints
# display_id: 1
# display_port: 8097
# display_single_pane_ncols: 0
# display_winsize: 256
# fineSize: [256, 256]
# gpu_ids: 0
# how_many: 50
# img_file: /content/Pluralistic/images/face_playing
# isTrain: False
# loadSize: [266, 266]
# mask_file: none
# mask_type: [1, 2]
# model: pluralistic
# nThreads: 8
# name: celeba_random
# no_augment: False
# no_flip: False
# no_rotation: False
# no_shuffle: False
# nsampling: 50
# ntest: inf
# output_scale: 4
# phase: test
# resize_or_crop: resize_and_crop
# results_dir: ./results/
# save_number: 10
# which_iter: latest
# ----------------End----------------
# testing images = 8
# ResEncoder(
#   (block0): ResBlockEncoderOptimized(
#     (conv1): SpectralNorm(
#       (module): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (conv2): SpectralNorm(
#       (module): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
# %cd /content/Pluralistic
# Out:
# /content/Pluralistic

# %%
# !pwd
# Out:
# /content/Pluralistic

# %%
# !pip install PyQt5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 103.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 43.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 30.5 MB/s eta 0:00:00
# ...

# %%
# !python -m visdom.server
# !python ui_main.py
# Out:
# Checking for scripts.
# ...
# It's Alive!
# INFO:root:Application Started
# INFO:root:Working directory: /root/.visdom
# You can navigate to http://e01411b309e0:8097
# Traceback (most recent call last):
#
# ^C
# Traceback (most recent call last):
#   File "/content/Pluralistic/ui_main.py", line 3, in <module>
#     from gui.ui_model import ui_model
#   File "/content/Pluralistic/gui/ui_model.py", line 14, in <module>
#     from gui.face_process.ffhq_align import FaceData
#   File "/content/Pluralistic/gui/face_process/ffhq_align.py", line 5, in <module>
#     import face_alignment
# ModuleNotFoundError: No module named 'face_alignment'
